# %% [markdown]
# # Template
#
# //

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "./data/"  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 54ms/step - accuracy: 0.1600 - loss: 2.6153 - val_accuracy: 0.1333 - val_loss: 2.5047
# Epoch 2/30
# 13/13 - 0s - 5ms/step - accuracy: 0.4800 - loss: 1.6951 - val_accuracy: 0.2333 - val_loss: 2.1975
# Epoch 3/30
# 13/13 - 0s - 6ms/step - accuracy: 0.6800 - loss: 1.4336 - val_accuracy: 0.4000 - val_loss: 2.0010
# Epoch 4/30
# 13/13 - 0s - 7ms/step - accuracy: 0.8400 - loss: 1.1029 - val_accuracy: 0.4667 - val_loss: 1.8254
# Epoch 5/30
# 13/13 - 0s - 5ms/step - accuracy: 0.8800 - loss: 0.9024 - val_accuracy: 0.5667 - val_loss: 1.7206
# Epoch 6/30
# 13/13 - 0s - 5ms/step - accuracy: 0.8800 - loss: 0.7437 - val_accuracy: 0.6000 - val_loss: 1.6290
# Epoch 7/30
# 13/13 - 0s - 5ms/step - accuracy: 0.9200 - loss: 0.6213 - val_accuracy: 0.6000 - val_loss: 1.5506
# Epoch 8/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9600 - loss: 0.5249 - val_accuracy: 0.6333 - val_loss: 1.4926
# Epoch 9/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9800 - loss: 0.4477 - val_accuracy: 0.6333 - val_loss: 1.4433
# Epoch 10/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.3863 - val_accuracy: 0.6333 - val_loss: 1.4025
# Epoch 11/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.3358 - val_accuracy: 0.6333 - val_loss: 1.3684
# Epoch 12/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2944 - val_accuracy: 0.6333 - val_loss: 1.3399
# Epoch 13/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2601 - val_accuracy: 0.6333 - val_loss: 1.3159
# Epoch 14/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2314 - val_accuracy: 0.6333 - val_loss: 1.2955
# Epoch 15/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2073 - val_accuracy: 0.6333 - val_loss: 1.2779
# Epoch 16/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1868 - val_accuracy: 0.6333 - val_loss: 1.2626
# Epoch 17/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1693 - val_accuracy: 0.6333 - val_loss: 1.2493
# Epoch 18/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1542 - val_accuracy: 0.6333 - val_loss: 1.2375
# Epoch 19/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1412 - val_accuracy: 0.6333 - val_loss: 1.2270
# Epoch 20/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1298 - val_accuracy: 0.6333 - val_loss: 1.2177
# Epoch 21/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1198 - val_accuracy: 0.6333 - val_loss: 1.2094
# Epoch 22/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1110 - val_accuracy: 0.6333 - val_loss: 1.2018
# Epoch 23/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1032 - val_accuracy: 0.6333 - val_loss: 1.1950
# Epoch 24/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0962 - val_accuracy: 0.6667 - val_loss: 1.1887
# Epoch 25/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0900 - val_accuracy: 0.6667 - val_loss: 1.1830
# Epoch 26/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0844 - val_accuracy: 0.6667 - val_loss: 1.1778
# Epoch 27/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0793 - val_accuracy: 0.6667 - val_loss: 1.1731
# Epoch 28/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0747 - val_accuracy: 0.6667 - val_loss: 1.1687
# Epoch 29/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0706 - val_accuracy: 0.6667 - val_loss: 1.1646
# Epoch 30/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0667 - val_accuracy: 0.6667 - val_loss: 1.1608

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 63ms/step - accuracy: 0.0600 - loss: 2.4146 - val_accuracy: 0.1333 - val_loss: 2.3062
# Epoch 2/30
# 13/13 - 0s - 6ms/step - accuracy: 0.2800 - loss: 2.0001 - val_accuracy: 0.2333 - val_loss: 2.1250
# Epoch 3/30
# 13/13 - 0s - 6ms/step - accuracy: 0.4800 - loss: 1.7081 - val_accuracy: 0.3000 - val_loss: 1.9736
# Epoch 4/30
# 13/13 - 0s - 6ms/step - accuracy: 0.6800 - loss: 1.4704 - val_accuracy: 0.3333 - val_loss: 1.8455
# Epoch 5/30
# 13/13 - 0s - 5ms/step - accuracy: 0.8200 - loss: 1.2727 - val_accuracy: 0.4667 - val_loss: 1.7370
# Epoch 6/30
# 13/13 - 0s - 5ms/step - accuracy: 0.8600 - loss: 1.1071 - val_accuracy: 0.5000 - val_loss: 1.6460
# Epoch 7/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9000 - loss: 0.9679 - val_accuracy: 0.5000 - val_loss: 1.5698
# Epoch 8/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9000 - loss: 0.8509 - val_accuracy: 0.5333 - val_loss: 1.5057
# Epoch 9/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9200 - loss: 0.7520 - val_accuracy: 0.5667 - val_loss: 1.4512
# Epoch 10/30
# 13/13 - 0s - 5ms/step - accuracy: 0.9800 - loss: 0.6681 - val_accuracy: 0.5667 - val_loss: 1.4045
# Epoch 11/30
# 13/13 - 0s - 5ms/step - accuracy: 0.9800 - loss: 0.5966 - val_accuracy: 0.5667 - val_loss: 1.3642
# Epoch 12/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.5353 - val_accuracy: 0.6333 - val_loss: 1.3292
# Epoch 13/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.4826 - val_accuracy: 0.6333 - val_loss: 1.2987
# Epoch 14/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.4369 - val_accuracy: 0.6333 - val_loss: 1.2719
# Epoch 15/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3971 - val_accuracy: 0.6333 - val_loss: 1.2484
# Epoch 16/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3624 - val_accuracy: 0.6333 - val_loss: 1.2275
# Epoch 17/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3319 - val_accuracy: 0.6333 - val_loss: 1.2090
# Epoch 18/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3051 - val_accuracy: 0.6333 - val_loss: 1.1925
# Epoch 19/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2813 - val_accuracy: 0.6333 - val_loss: 1.1777
# Epoch 20/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2602 - val_accuracy: 0.6333 - val_loss: 1.1643
# Epoch 21/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.2414 - val_accuracy: 0.6333 - val_loss: 1.1523
# Epoch 22/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2245 - val_accuracy: 0.6333 - val_loss: 1.1415
# Epoch 23/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2094 - val_accuracy: 0.6333 - val_loss: 1.1316
# Epoch 24/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1957 - val_accuracy: 0.6333 - val_loss: 1.1226
# Epoch 25/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1834 - val_accuracy: 0.6333 - val_loss: 1.1145
# Epoch 26/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.1722 - val_accuracy: 0.6333 - val_loss: 1.1070
# Epoch 27/30
# 13/13 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.1620 - val_accuracy: 0.6333 - val_loss: 1.1001
# Epoch 28/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1528 - val_accuracy: 0.6333 - val_loss: 1.0938
# Epoch 29/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1443 - val_accuracy: 0.6333 - val_loss: 1.0879
# Epoch 30/30
# 13/13 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.1365 - val_accuracy: 0.6333 - val_loss: 1.0825

# %%
# import matplotlib.pyplot as plt

# plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
